# %% [markdown]
# # Import essintial Libraries

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load data excel or csv file.

# %%
df=pd.read_excel(r"C:\Users\Dell\Desktop\Desktop Document\My_Project_testing\data\FinalAQI_Compiled sheet of Ratnapark Data 2020_PM2.5.xlsx")

# %%
df.head()
# Out:
#   Station_name  Longitude  Latitude       DateTime Temp_Max Temp_Min Temp_Avg  \
# 0    Ratnapark      85.31      27.7  01/01/2017 00      9.6        9  9.35333
# 1    Ratnapark      85.31      27.7  01/01/2017 01      9.2      8.5     8.81
# 2    Ratnapark      85.31      27.7  01/01/2017 02      8.7      7.8     8.34
# 3    Ratnapark      85.31      27.7  01/01/2017 03      8.1      7.7  7.78667
# 4    Ratnapark      85.31      27.7  01/01/2017 04      7.8      7.4  7.61897
#
#   RH_Max RH_Min   RH_Avg  ...  Wd_Min   Wd_Avg  Ws_Max Ws_Min    Ws_Avg  \
# 0   87.9   85.1  86.4883  ...     1.9  176.011     0.9    0.3  0.538889
# 1   89.6   87.3  88.5967  ...   146.1  181.544     0.9    0.3  0.551111
# 2     93   89.5  91.2067  ...   134.6  184.267     0.7    0.3   0.44186
# 3   93.7   91.8  92.5683  ...     1.7  176.111     0.9    0.3  0.582609
# 4   93.6   91.8  92.7386  ...    32.8   175.39     0.7    0.3       0.5
#
#     PM2.5_Max  PM2.5_Min  PM2.5_Avg AQI_PM2.5 AQI Category
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30389 entries, 0 to 30388
# Data columns (total 27 columns):
# Station_name    30389 non-null object
# Longitude       30389 non-null float64
# Latitude        30389 non-null float64
# DateTime        30389 non-null object
# Temp_Max        30389 non-null object
# Temp_Min        30389 non-null object
# Temp_Avg        30389 non-null object
# RH_Max          30389 non-null object
# RH_Min          30389 non-null object
# RH_Avg          30389 non-null object
# Pre_Max         30389 non-null float64
# Pre_Min         30389 non-null float64
# Pre_Avg         30389 non-null float64
# PP_Max          30386 non-null object
# PP_Min          30386 non-null object
# PP_Avg          30387 non-null object
# Wd_Max          30389 non-null object
# Wd_Min          30389 non-null object
# Wd_Avg          30389 non-null object
# Ws_Max          30389 non-null object
# Ws_Min          30389 non-null object
# Ws_Avg          30389 non-null object
# ...

# %%
df.shape
# Out:
# (30389, 27)

# %%
df.columns
# Out:
# Index(['Station_name', 'Longitude', 'Latitude', 'DateTime', 'Temp_Max',
#        'Temp_Min', 'Temp_Avg', 'RH_Max', 'RH_Min', 'RH_Avg', 'Pre_Max',
#        'Pre_Min', 'Pre_Avg', 'PP_Max', 'PP_Min', 'PP_Avg', 'Wd_Max', 'Wd_Min',
#        'Wd_Avg', 'Ws_Max', 'Ws_Min', 'Ws_Avg', 'PM2.5_Max', 'PM2.5_Min',
#        'PM2.5_Avg', 'AQI_PM2.5', 'AQI Category'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Station_name     object
# Longitude       float64
# Latitude        float64
# DateTime         object
# Temp_Max         object
# Temp_Min         object
# Temp_Avg         object
# RH_Max           object
# RH_Min           object
# RH_Avg           object
# Pre_Max         float64
# Pre_Min         float64
# Pre_Avg         float64
# PP_Max           object
# PP_Min           object
# PP_Avg           object
# Wd_Max           object
# Wd_Min           object
# Wd_Avg           object
# Ws_Max           object
# Ws_Min           object
# Ws_Avg           object
# PM2.5_Max       float64
# PM2.5_Min       float64
# PM2.5_Avg       float64
# AQI_PM2.5       float64
# AQI Category     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Station_name      0
# Longitude         0
# Latitude          0
# DateTime          0
# Temp_Max          0
# Temp_Min          0
# Temp_Avg          0
# RH_Max            0
# RH_Min            0
# RH_Avg            0
# Pre_Max           0
# Pre_Min           0
# Pre_Avg           0
# PP_Max            3
# PP_Min            3
# PP_Avg            2
# Wd_Max            0
# Wd_Min            0
# Wd_Avg            0
# Ws_Max            0
# Ws_Min            0
# Ws_Avg            0
# PM2.5_Max         0
# PM2.5_Min         0
# PM2.5_Avg         0
# AQI_PM2.5       111
# AQI Category    111
# dtype: int64

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
df=df.dropna()

# %%
df.dtypes
# Out:
# Station_name     object
# Longitude       float64
# Latitude        float64
# DateTime         object
# Temp_Max         object
# Temp_Min         object
# Temp_Avg         object
# RH_Max           object
# RH_Min           object
# RH_Avg           object
# Pre_Max         float64
# Pre_Min         float64
# Pre_Avg         float64
# PP_Max           object
# PP_Min           object
# PP_Avg           object
# Wd_Max           object
# Wd_Min           object
# Wd_Avg           object
# Ws_Max           object
# Ws_Min           object
# Ws_Avg           object
# PM2.5_Max       float64
# PM2.5_Min       float64
# PM2.5_Avg       float64
# AQI_PM2.5       float64
# AQI Category     object
# dtype: object

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
cols = list(df.columns)[4:]
for i in cols:
    df[i] = pd.to_numeric(df[i], errors= 'coerce')
    
df[cols]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         Temp_Max   Temp_Min   Temp_Avg     RH_Max     RH_Min     RH_Avg  \
# 0       9.600000   9.000000   9.353333  87.900002  85.099998  86.488333
# 1       9.200000   8.500000   8.810000  89.599998  87.300003  88.596667
# 2       8.700000   7.800000   8.340000  93.000000  89.500000  91.206667
# 3       8.100000   7.700000   7.786667  93.699997  91.800003  92.568333
# 4       7.800000   7.400000   7.618965  93.599998  91.800003  92.738597
# 5       7.800000   7.300000   7.503333  94.199997  92.500000  93.291666
# ...

# %%
df.describe().T
# Out:
#              count        mean        std         min         25%         50%  \
# Temp_Avg   29828.0   18.615831   6.141484    1.746667   14.183333   19.913333
# RH_Avg     29828.0   74.125742  18.372844   12.375000   61.767514   77.809092
# Pre_Avg    30275.0  868.884763   3.970026  854.435599  865.998165  869.083333
# PP_Avg     29828.0    0.189253   1.216853    0.000000    0.000000    0.000000
# Wd_Avg     29828.0  166.470756  56.901612    7.730000  129.213937  166.942428
# Ws_Avg     29828.0    0.928704   0.572884    0.015000    0.521053    0.775000
# PM2.5_Avg  30275.0   41.184076  34.461792    0.600000   14.983503   30.501587
#
#                   75%         max
# Temp_Avg    23.108333   32.375000
# RH_Avg      88.838333  100.000000
# Pre_Avg    871.866658  880.599981
# PP_Avg       0.000000   32.088372
# Wd_Avg     196.937046  336.100006
# Ws_Avg       1.198276    4.626667
# PM2.5_Avg   58.415833  240.968751

# %%
df= df[['Temp_Avg','RH_Avg','Pre_Avg','PP_Avg','Wd_Avg','Ws_Avg','PM2.5_Avg','AQI_PM2.5']]
df.columns=['Temp_Avg', 'RH_Avg', 'Pre_Avg', 'PP_Avg', 'Wd_Avg', 'Ws_Avg', 'PM2.5_Avg','AQI_PM2.5']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-0ce5b8ac5905> in <module>
# ----> 1 df= df[['Temp_Avg','RH_Avg','Pre_Avg','PP_Avg','Wd_Avg','Ws_Avg','PM2.5_Avg','AQI_PM2.5']]
#       2 df.columns=['Temp_Avg', 'RH_Avg', 'Pre_Avg', 'PP_Avg', 'Wd_Avg', 'Ws_Avg', 'PM2.5_Avg','AQI_PM2.5']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
# ...

# %%
df.describe().T
# Out:
#              count        mean        std         min         25%         50%  \
# Temp_Avg   29828.0   18.615831   6.141484    1.746667   14.183333   19.913333
# RH_Avg     29828.0   74.125742  18.372844   12.375000   61.767514   77.809092
# Pre_Avg    30275.0  868.884763   3.970026  854.435599  865.998165  869.083333
# PP_Avg     29828.0    0.189253   1.216853    0.000000    0.000000    0.000000
# Wd_Avg     29828.0  166.470756  56.901612    7.730000  129.213937  166.942428
# Ws_Avg     29828.0    0.928704   0.572884    0.015000    0.521053    0.775000
# PM2.5_Avg  30275.0   41.184076  34.461792    0.600000   14.983503   30.501587
#
#                   75%         max
# Temp_Avg    23.108333   32.375000
# RH_Avg      88.838333  100.000000
# Pre_Avg    871.866658  880.599981
# PP_Avg       0.000000   32.088372
# Wd_Avg     196.937046  336.100006
# Ws_Avg       1.198276    4.626667
# PM2.5_Avg   58.415833  240.968751

# %%
sns.pairplot(df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
X=df.iloc[:,:-1] ## independent features
y=df.iloc[:,-1]

# %%
X.isnull()
# Out:
#        Temp_Avg  RH_Avg  Pre_Avg  PP_Avg  Wd_Avg  Ws_Avg
# 0         False   False    False   False   False   False
# 1         False   False    False   False   False   False
# 2         False   False    False   False   False   False
# 3         False   False    False   False   False   False
# 4         False   False    False   False   False   False
# 5         False   False    False   False   False   False
# 6         False   False    False   False   False   False
# 7         False   False    False   False   False   False
# 8         False   False    False   False   False   False
# 9         False   False    False   False   False   False
# 10        False   False    False   False   False   False
# 11        False   False    False   False   False   False
# 12        False   False    False   False   False   False
# 13        False   False    False   False   False   False
# 14        False   False    False   False   False   False
# ...

# %%
y.isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 30359    False
# 30360    False
# 30361    False
# 30362    False
# 30363    False
# 30364    False
# 30365    False
# 30366    False
# 30367    False
# 30368    False
# 30369    False
# 30370    False
# 30371    False
# 30372    False
# 30373    False
# 30374    False
# 30375    False
# 30376    False
# 30377    False
# 30378    False
# 30379    False
# 30380    False
# 30381    False
# 30382    False
# 30383    False
# 30384    False
# 30385    False
# ...

# %%
X.head
# Out:
# <bound method NDFrame.head of         Temp_Avg     RH_Avg     Pre_Avg    PP_Avg      Wd_Avg    Ws_Avg
# 0       9.353333  86.488333  873.761665  0.000000  176.011430  0.538889
# 1       8.810000  88.596667  873.650002  0.000000  181.544445  0.551111
# 2       8.340000  91.206667  873.494994  0.000000  184.267442  0.441860
# 3       7.786667  92.568333  873.189984  0.000000  176.110869  0.582609
# 4       7.618965  92.738597  872.977592  0.000000  175.390476  0.500000
# 5       7.503333  93.291666  873.113325  0.000000  178.740817  0.510204
# 6       7.610000  91.746666  873.810000  0.000000  170.856522  0.634783
# 7       8.061667  90.076667  874.759996  0.000000  187.430358  0.594643
# 8       9.360000  85.493333  875.631666  0.000000  188.629168  0.858333
# 9      10.726667  79.191667  876.183322  0.000000  261.314817  0.716667
# 10     13.803333  66.776666  876.056666  0.000000  215.835849  0.777358
# 11     13.268333  69.311667  875.453328  0.125000  175.283333  1.703333
# ...

# %%
y.head
# Out:
# <bound method NDFrame.head of 0         90.363333
# 1         81.936667
# 2         81.056667
# 3         78.938333
# 4         84.759650
# 5         82.195000
# 6         93.663333
# 7        115.996667
# 8        131.123333
# 9        130.836667
# 10        98.183334
# 11        95.145000
# 12        49.321667
# 13        42.943333
# 14        51.531666
# 15        74.568001
# 16        84.294915
# 17        92.694915
# 18       128.846666
# 19       205.828333
# 20       223.241666
# 21       194.185001
# 22       199.625001
# 23       147.421053
# 24       138.918333
# 25       105.788334
# 26        97.108334
# 27        82.238333
# 28        89.663333
# 29       103.786666
#             ...
# 30359     14.204615
# 30360     23.854687
# 30361     12.822222
# 30362     10.801587
# 30363     11.704839
# 30364     13.378125
# 30365      8.589062
# 30366      7.790625
# 30367      7.731250
# 30368      8.163492
# 30369      9.863492
# 30370     11.084375
# 30371     16.847619
# ...

# %%
df.corr()
# Out:
#            Temp_Avg    RH_Avg   Pre_Avg    PP_Avg    Wd_Avg    Ws_Avg  \
# Temp_Avg   1.000000 -0.328173 -0.606804  0.037030  0.300118  0.529026
# RH_Avg    -0.328173  1.000000 -0.096008  0.135130 -0.550317 -0.612169
# Pre_Avg   -0.606804 -0.096008  1.000000 -0.110099 -0.090029 -0.236788
# PP_Avg     0.037030  0.135130 -0.110099  1.000000 -0.059321  0.042160
# Wd_Avg     0.300118 -0.550317 -0.090029 -0.059321  1.000000  0.624471
# Ws_Avg     0.529026 -0.612169 -0.236788  0.042160  0.624471  1.000000
# PM2.5_Avg -0.584767 -0.050404  0.503443 -0.106701 -0.050351 -0.241531
#
#            PM2.5_Avg
# Temp_Avg   -0.584767
# RH_Avg     -0.050404
# Pre_Avg     0.503443
# PP_Avg     -0.106701
# Wd_Avg     -0.050351
# Ws_Avg     -0.241531
# PM2.5_Avg   1.000000

# %%
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
corrmat.index
# Out:
# Index(['Temp_Avg', 'RH_Avg', 'Pre_Avg', 'PP_Avg', 'Wd_Avg', 'Ws_Avg',
#        'PM2.5_Avg'],
#       dtype='object')

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-00a908337bfe> in <module>
#       2 import matplotlib.pyplot as plt
#       3 model = ExtraTreesRegressor()
# ----> 4 model.fit(X,y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     248
#     249         # Validate or convert input data
# --> 250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     251         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     252         if sample_weight is not None:
#
# ...
